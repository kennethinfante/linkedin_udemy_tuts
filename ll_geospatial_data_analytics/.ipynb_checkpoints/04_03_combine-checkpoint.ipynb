# %% [markdown]
# # Combine and compare spatial data sets

# %%
import geopandas as gpd

# %%
nybb = gpd.read_file(gpd.datasets.get_path('nybb'))
nybb.head(3)
# Out:
#    BoroCode       BoroName     Shape_Leng    Shape_Area  \
# 0         5  Staten Island  330470.010332  1.623820e+09
# 1         4         Queens  896344.047763  3.045213e+09
# 2         3       Brooklyn  741080.523166  1.937479e+09
#
#                                             geometry
# 0  MULTIPOLYGON (((970217.022 145643.332, 970227....
# 1  MULTIPOLYGON (((1029606.077 156073.814, 102957...
# 2  MULTIPOLYGON (((1021176.479 151374.797, 102100...

# %%
gdf = gpd.read_file('2010 Neighborhood Tabulation Areas (NTAs).geojson')
gdf.head(3)
# Out:
#   ntacode     shape_area county_fips     ntaname     shape_leng boro_name  \
# 0    QN08   77412747.756         081  St. Albans  45401.3169155    Queens
# 1    BK50  82089678.5561         047    Canarsie  43703.6099368  Brooklyn
# 2    BX41   14716710.849         005  Mount Hope  18937.2480746     Bronx
#
#   boro_code                                           geometry
# 0         4  MULTIPOLYGON (((-73.75205 40.70523, -73.75174 ...
# 1         3  MULTIPOLYGON (((-73.88834 40.64671, -73.88835 ...
# 2         2  MULTIPOLYGON (((-73.89561 40.85457, -73.89662 ...

# %%
import matplotlib.pyplot as plt

f, ax = plt.subplots(1,2,figsize=(10,5))

nybb.plot(ax=ax[0], cmap = 'tab20')
gdf.plot(ax=ax[1], cmap = 'tab20')

ax[0].set_title('NYC boroughs')
ax[1].set_title('NYC neigbhorhoods')
# Out:
# Text(0.5, 1.0, 'NYC neigbhorhoods')

# %%
print(nybb.crs)
print(gdf.crs)
# Out:
# epsg:2263
# epsg:4326

# %%
gdf_local = gdf.to_crs(nybb.crs)

# %%
print(gdf_local.crs)
# Out:
# epsg:2263

# %%
gdf_local.head(3)
# Out:
#   ntacode     shape_area county_fips     ntaname     shape_leng boro_name  \
# 0    QN08   77412747.756         081  St. Albans  45401.3169155    Queens
# 1    BK50  82089678.5561         047    Canarsie  43703.6099368  Brooklyn
# 2    BX41   14716710.849         005  Mount Hope  18937.2480746     Bronx
#
#   boro_code                                           geometry
# 0         4  MULTIPOLYGON (((1052996.196 196307.658, 105308...
# 1         3  MULTIPOLYGON (((1015236.151 174910.303, 101523...
# 2         2  MULTIPOLYGON (((1013128.525 250637.931, 101284...

# %%
nybb.head(3)
# Out:
#    BoroCode       BoroName     Shape_Leng    Shape_Area  \
# 0         5  Staten Island  330470.010332  1.623820e+09
# 1         4         Queens  896344.047763  3.045213e+09
# 2         3       Brooklyn  741080.523166  1.937479e+09
#
#                                             geometry
# 0  MULTIPOLYGON (((970217.022 145643.332, 970227....
# 1  MULTIPOLYGON (((1029606.077 156073.814, 102957...
# 2  MULTIPOLYGON (((1021176.479 151374.797, 102100...

# %%
df_group_1 = gdf_local.groupby(by = 'boro_name').count()[['geometry']].rename(columns = {'geometry' : 'ngh_cnt_1'})
df_group_1
# Out:
#                ngh_cnt_1
# boro_name
# Bronx                 38
# Brooklyn              51
# Manhattan             29
# Queens                58
# Staten Island         19

# %%
gdf_over = gpd.overlay(nybb, gdf_local[['ntaname', 'geometry']])
gdf_over.head(3)
# Out:
#    BoroCode       BoroName     Shape_Leng    Shape_Area  \
# 0         5  Staten Island  330470.010332  1.623820e+09
# 1         5  Staten Island  330470.010332  1.623820e+09
# 2         5  Staten Island  330470.010332  1.623820e+09
#
#                                   ntaname  \
# 0  Charleston-Richmond Valley-Tottenville
# 1                           Port Richmond
# 2                  New Dorp-Midland Beach
#
#                                             geometry
# 0  POLYGON ((922431.801 122456.465, 922417.134 12...
# 1  MULTIPOLYGON (((950641.549 173056.629, 950648....
# 2  POLYGON ((960721.609 147492.642, 960370.525 14...

# %%
df_group_2 = gdf_over.groupby(by = 'BoroName').count()
df_group_2 = df_group_2[['ntaname']].rename(columns = {'ntaname' : 'ngh_cnt_2'})
df_group_2
# Out:
#                ngh_cnt_2
# BoroName
# Bronx                 41
# Brooklyn              59
# Manhattan             37
# Queens                64
# Staten Island         20

# %%
df_group = df_group_1.merge(df_group_2, left_index = True, right_index = True)
df_group
# Out:
#                ngh_cnt_1  ngh_cnt_2
# boro_name
# Bronx                 38         41
# Brooklyn              51         59
# Manhattan             29         37
# Queens                58         64
# Staten Island         19         20

# %%
df_group.corr()
# Out:
#            ngh_cnt_1  ngh_cnt_2
# ngh_cnt_1   1.000000   0.989049
# ngh_cnt_2   0.989049   1.000000

# %%
f, ax = plt.subplots(1,1,figsize=(10,10))
nybb.plot(ax=ax, color = 'none', edgecolor = 'b')
gdf_local.plot(ax=ax, color = 'none', edgecolor = 'r')
# Out:
# <Axes: >
